# %% [markdown]
# # 🛡️ HMARL-SOC Training
# **Hierarchical Multi-Agent RL for SOC** — ITC-CSCC 2026
#
# Runtime → Change runtime type → **GPU (T4)**

# %%
# Step 1: Clone repo & install
# !git clone https://github.com/nutthakorn7/HMARL-SOC.git
# %cd HMARL-SOC
# !pip install -q torch gymnasium numpy pyyaml matplotlib tensorboard

# %%
# Step 2: Verify GPU
import torch
print(f"GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'CPU only'}")
print(f"CUDA available: {torch.cuda.is_available()}")

# %%
# Step 3: Train! (10K episodes ~15 min on T4)
# !python train.py --config configs/default.yaml --episodes 10000 --seed 42 --save-dir /content/checkpoints

# %%
# Step 4: Multi-seed training (5 seeds for paper)
for seed in [42, 123, 456, 789, 1024]:
    print(f"\n{'='*60}")
    print(f"Training seed {seed}")
    print(f"{'='*60}")
    # !python train.py --config configs/default.yaml --episodes 10000 --seed {seed} --save-dir /content/checkpoints

# %%
# Step 5: Evaluate best model
# !python evaluate.py --checkpoint /content/checkpoints/checkpoint_best.pt --episodes 1000

# %%
# Step 6: Download results
from google.colab import files
import shutil
shutil.make_archive('/content/hmarl_soc_results', 'zip', '/content/checkpoints')
files.download('/content/hmarl_soc_results.zip')
